# %%
#importing  Dependencies / Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as  plt
# %matplotlib inline

# %%
#reading and creating dataframe from the csv file of 311 nyc
nyc_df = pd.read_csv('E:\\Simplilearn\\Python\\Projects\\311_Service_Requests_from_2010_to_Present.csv', nrows=10000,parse_dates = ['Created Date','Closed Date'])

# %%
#printing top  5 rows
nyc_df.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:57   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:03   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:13   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:42   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# 2                     No Access  Street/Sidewalk       10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk       10461.0
# 4              Blocked Sidewalk  Street/Sidewalk       11373.0
#
#         Incident Address                    ...                     \
# 0    71 VERMILYEA AVENUE                    ...
# 1        27-07 23 AVENUE                    ...
# 2  2897 VALENTINE AVENUE                    ...
# 3    2940 BAISLEY AVENUE                    ...
# 4          87-14 57 ROAD                    ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1                    NaN             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
# 3                    NaN             NaN             NaN                 NaN
# 4                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                  Location
# 0  40.865682 -73.923501   (40.86568153633767, -73.92350095571744)
# 1  40.775945 -73.915094  (40.775945312321085, -73.91509393898605)
# 2  40.870325 -73.888525  (40.870324522111424, -73.88852464418646)
# 3  40.835994 -73.828379   (40.83599404683083, -73.82837939584206)
# 4  40.733060 -73.874170  (40.733059618956815, -73.87416975810375)
#
# [5 rows x 53 columns]

# %%
#shape of dataframe
nyc_df.shape
# Out:
# (10000, 53)

# %%
#It has 51 columns. So, we will list it out 
list(nyc_df.columns)
# Out:
# ['Unique Key',
#  'Created Date',
#  'Closed Date',
#  'Agency',
#  'Agency Name',
#  'Complaint Type',
#  'Descriptor',
#  'Location Type',
#  'Incident Zip',
#  'Incident Address',
#  'Street Name',
#  'Cross Street 1',
#  'Cross Street 2',
#  'Intersection Street 1',
#  'Intersection Street 2',
#  'Address Type',
#  'City',
#  'Landmark',
#  'Facility Type',
#  'Status',
#  'Due Date',
#  'Resolution Description',
#  'Resolution Action Updated Date',
#  'Community Board',
#  'Borough',
#  'X Coordinate (State Plane)',
#  'Y Coordinate (State Plane)',
#  'Park Facility Name',
#  'Park Borough',
#  'School Name',
#  'School Number',
#  'School Region',
#  'School Code',
#  'School Phone Number',
#  'School Address',
#  'School City',
#  'School State',
#  'School Zip',
#  'School Not Found',
#  'School or Citywide Complaint',
#  'Vehicle Type',
#  'Taxi Company Borough',
#  'Taxi Pick Up Location',
#  'Bridge Highway Name',
#  'Bridge Highway Direction',
#  'Road Ramp',
#  'Bridge Highway Segment',
#  'Garage Lot Name',
#  'Ferry Direction',
#  'Ferry Terminal Name',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
#info of dataframe
nyc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 53 columns):
# Unique Key                        10000 non-null int64
# Created Date                      10000 non-null datetime64[ns]
# Closed Date                       9943 non-null datetime64[ns]
# Agency                            10000 non-null object
# Agency Name                       10000 non-null object
# Complaint Type                    10000 non-null object
# Descriptor                        9822 non-null object
# Location Type                     10000 non-null object
# Incident Zip                      9934 non-null float64
# Incident Address                  8893 non-null object
# Street Name                       8893 non-null object
# Cross Street 1                    8752 non-null object
# Cross Street 2                    8736 non-null object
# Intersection Street 1             1101 non-null object
# Intersection Street 2             1087 non-null object
# Address Type                      9928 non-null object
# City                              9934 non-null object
# Landmark                          6 non-null object
# Facility Type                     9945 non-null object
# Status                            10000 non-null object
# Due Date                          10000 non-null object
# Resolution Description            10000 non-null object
# Resolution Action Updated Date    9945 non-null object
# Community Board                   10000 non-null object
# Borough                           10000 non-null object
# X Coordinate (State Plane)        9914 non-null float64
# Y Coordinate (State Plane)        9914 non-null float64
# Park Facility Name                10000 non-null object
# Park Borough                      10000 non-null object
# School Name                       10000 non-null object
# School Number                     10000 non-null object
# School Region                     10000 non-null object
# School Code                       10000 non-null object
# School Phone Number               10000 non-null object
# School Address                    10000 non-null object
# School City                       10000 non-null object
# School State                      10000 non-null object
# School Zip                        10000 non-null object
# School Not Found                  10000 non-null object
# School or Citywide Complaint      0 non-null float64
# Vehicle Type                      0 non-null float64
# Taxi Company Borough              0 non-null float64
# Taxi Pick Up Location             0 non-null float64
# Bridge Highway Name               6 non-null object
# Bridge Highway Direction          6 non-null object
# Road Ramp                         5 non-null object
# Bridge Highway Segment            5 non-null object
# Garage Lot Name                   0 non-null float64
# Ferry Direction                   0 non-null float64
# Ferry Terminal Name               0 non-null float64
# Latitude                          9914 non-null float64
# Longitude                         9914 non-null float64
# Location                          9914 non-null object
# dtypes: datetime64[ns](2), float64(12), int64(1), object(38)
# memory usage: 4.0+ MB

# %%
#Display the complaint type and city together    
nyc_df.dropna(subset=['City'] ,inplace = True)

# %%
nyc_df['Complaint Type'].value_counts().nlargest(10)
# Out:
# Blocked Driveway           3345
# Illegal Parking            2825
# Noise - Commercial         1077
# Noise - Street/Sidewalk     836
# Derelict Vehicle            630
# Noise - Vehicle             390
# Animal Abuse                249
# Homeless Encampment         148
# Vending                     137
# Traffic                     110
# Name: Complaint Type, dtype: int64

# %%
nyc_df.groupby(['Complaint Type'])['City'].value_counts().nlargest(10)
# Out:
# Complaint Type           City
# Blocked Driveway         BROOKLYN    1191
# Illegal Parking          BROOKLYN    1064
# Blocked Driveway         BRONX        593
# Noise - Commercial       NEW YORK     436
# Illegal Parking          NEW YORK     383
# Noise - Street/Sidewalk  NEW YORK     383
# Noise - Commercial       BROOKLYN     332
# Illegal Parking          BRONX        289
# Derelict Vehicle         BROOKLYN     229
# Noise - Street/Sidewalk  BROOKLYN     217
# Name: City, dtype: int64

# %%
#visualize only top twenty complaint data
nyc_df['Complaint Type'].value_counts().nlargest(10).plot(kind='bar', title='Complaint Type',figsize=(10,6))
plt.show()

# %%
nyc_df.groupby(['Complaint Type'])['City'].value_counts().nlargest(50).plot(kind='bar', figsize=(10,6))
plt.show()
